# %% [markdown]
# 1. First two commands are to use the .env environment variable file for the project. In this scenario for this lab we are setting up the use of the OPENAI API KEY

# %%
from dotenv import load_dotenv

# %% [markdown]
# 2. By default it is the system env vars that are used first, so we need to set this parameter to override using system env var and use the .env file instead.

# %%
load_dotenv(override=True)
# Out:
# True

# %%
import os
openai_api_key = os.getenv("OPENAI_API_KEY")

if openai_api_key:
    print(f"OPENAI_API_KEY exists and begins with {openai_api_key[:8]}...")
else:
    print("OPENAI_API_KEY is not set - please check your .env file or configure it first")
# Out:
# OPENAI_API_KEY exists and begins with sk-proj-...

# %%
from openai import OpenAI
